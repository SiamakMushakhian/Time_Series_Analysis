# %% [markdown]
# # Load Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
current_dir = Path('.').resolve()

# %%
file_path = current_dir / 'data/prediction.csv'

# %%
df = pd.read_csv(file_path, parse_dates=[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10837 entries, 0 to 10836
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Time        10837 non-null  datetime64[ns]
#  1   Production  10837 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 169.5 KB

# %%
df.head()
# Out:
#                  Time    Production
# 0 2022-01-02 14:15:00   1954.666673
# 1 2022-01-02 14:30:00   2309.333426
# 2 2022-01-02 14:45:00  12375.333480
# 3 2022-01-02 15:00:00      0.000000
# 4 2022-01-02 15:15:00      0.000000

# %% [markdown]
# # Resampling

# %% [markdown]
# No need for resampling.

# %% [markdown]
# # Time Series Visualization

# %%
plt.figure(figsize=(13, 5))
df['Production'].plot()
plt.show()

# %%
vz = df.copy()

# %%
vz.index = vz['Time']

# %%
vz.head()
# Out:
#                                    Time    Production
# Time
# 2022-01-02 14:15:00 2022-01-02 14:15:00   1954.666673
# 2022-01-02 14:30:00 2022-01-02 14:30:00   2309.333426
# 2022-01-02 14:45:00 2022-01-02 14:45:00  12375.333480
# 2022-01-02 15:00:00 2022-01-02 15:00:00      0.000000
# 2022-01-02 15:15:00 2022-01-02 15:15:00      0.000000

# %%
plt.figure(figsize=(13, 5))
vz['Production'].plot()
plt.show()

# %% [markdown]
# ## Zoom In

# %%
vz2 = vz[(vz['Time'] > '2022-01-01') & (vz['Time'] <= '2022-01-08')].copy()

# %%
plt.figure(figsize=(13, 5))
vz2['Production'].plot()
plt.show()

# %% [markdown]
# ## Trendline

# %%
plt.figure(figsize=(13, 5))
sns.regplot(x=df.index.values, y=df['Production'])
plt.show()

# %%
plt.figure(figsize=(13, 5))
sns.regplot(x=df.index.values, y=df['Production'], order=3)
plt.show()

# %% [markdown]
# ## Remove Seasonality

# %%
df['Month'] = df['Time'].dt.month

# %%
df.head()
# Out:
#                  Time    Production  Month
# 0 2022-01-02 14:15:00   1954.666673      1
# 1 2022-01-02 14:30:00   2309.333426      1
# 2 2022-01-02 14:45:00  12375.333480      1
# 3 2022-01-02 15:00:00      0.000000      1
# 4 2022-01-02 15:15:00      0.000000      1

# %%
plt.figure(figsize=(13, 5))
df.groupby('Month')['Production'].mean().plot()
plt.show()

# %%
df['Day'] = df['Time'].dt.day

# %%
plt.figure(figsize=(13, 5))
df.groupby('Day')['Production'].mean().plot()
plt.show()

# %% [markdown]
# ## Create Lag Plot

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df['Production'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(df['Production'], lag=2)
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 2)'>

# %% [markdown]
# ## Autocorrelation Plot

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(df['Production'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# # Decomposing Time Series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df.index = df['Time']

# %%
df = df.set_index('Time').asfreq('15T')

# %%
df.isnull().sum()
# Out:
# Production    8068
# Month         8068
# Day           8068
# dtype: int64

# %%
result = seasonal_decompose(df['Production'], model='additive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 result = seasonal_decompose(df['Production'], model='additive')
#
# File ~/anaconda3/envs/ts/lib/python3.10/site-packages/statsmodels/tsa/seasonal.py:146, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     143 nobs = len(x)
#     145 if not np.all(np.isfinite(x)):
# --> 146     raise ValueError("This function does not handle missing values")
#     147 if model.startswith("m"):
#     148     if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
df.head()

# %%
df.index

# %%
# check the frequency of the data
print(df.index.freq, df['Time'].dt.freq)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/ts/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/anaconda3/envs/ts/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/envs/ts/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 # check the frequency of the data
# ----> 2 print(df.index.freq, df['Time'].dt.freq)
#
# File ~/anaconda3/envs/ts/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/envs/ts/lib/python3.10/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Time'

# %%
def add_freq(idx, freq=None):
    """
    Add a frequency attribute to idx, through inference or directly.
    Returns a copy.  If `freq` is None, it is inferred.
    """

    idx = idx.copy()
    if freq is None:
        if idx.freq is None:
            freq = pd.infer_freq(idx)
        else:
            return idx
    idx.freq = pd.tseries.frequencies.to_offset(freq)
    if idx.freq is None:
        raise AttributeError('no discernible frequency found to `idx`.  Specify'
                             ' a frequency string with `freq`.')
    return idx

# %%
idx=pd.to_datetime(['2022-01-02 14:15:00', '2022-01-02 14:30:00', '2022-01-02 14:45:00'])  # freq=None

# %%
print(add_freq(idx))

# %%
idx

# %%
add_freq(df.index, freq='15T')

# %%
tdelta = df.index[1] - df.index[0]
tdelta

# %%
df.index.freq = '15T'

# %%
result = seasonal_decompose(df['Production'], model='additive')
